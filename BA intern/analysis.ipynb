# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Task 1 : Data Overview
# _Objective: Understand the dataset structure_

# %%
data = pd.read_csv("Data_set 2.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %%
data.head(10)
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
# 5  Female   24                 No             7              5           4
# 6  Female   27                Yes             3              6           4
# 7    Male   21                Yes             2              3           7
# 8    Male   35                Yes             2              4           7
# 9    Male   31                Yes             1              3           7
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# ...

# %% [markdown]
# The dataset is demographic and investment-related information about individuals

# %%
data.describe(include="all")
# Out:
#        gender        age Investment_Avenues  Mutual_Funds  Equity_Market  \
# count      40  40.000000                 40     40.000000      40.000000
# unique      2        NaN                  2           NaN            NaN
# top      Male        NaN                Yes           NaN            NaN
# freq       25        NaN                 37           NaN            NaN
# mean      NaN  27.800000                NaN      2.550000       3.475000
# std       NaN   3.560467                NaN      1.197219       1.131994
# min       NaN  21.000000                NaN      1.000000       1.000000
# 25%       NaN  25.750000                NaN      2.000000       3.000000
# 50%       NaN  27.000000                NaN      2.000000       4.000000
# 75%       NaN  30.000000                NaN      3.000000       4.000000
# max       NaN  35.000000                NaN      7.000000       6.000000
#
#         Debentures  Government_Bonds  Fixed_Deposits        PPF       Gold  \
# ...

# %% [markdown]
# ## Task 2 : Gender Distribution
#
# _Objective: Visualize gender distribution in
#  the dataset_

# %%
gender_counts = data['gender'].value_counts()
print(gender_counts)
# Out:
# gender
# Male      25
# Female    15
# Name: count, dtype: int64

# %%
# Building a Bar chart :
gender_counts.plot(kind='bar', color=['skyblue', 'pink'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Building a Pie chart
gender_counts.plot(kind='pie', autopct='%1.1f%%', colors=['skyblue', 'pink'])
plt.title('Gender Distribution')
plt.ylabel('')  
plt.show()

# %% [markdown]
# **_There is a notable gender disparity in the dataset, with males (62.5%) outnumbering females (37.5%), indicating a male-dominated sample_**

# %% [markdown]
# ## Task 3 : Descriptive Statistics
# _Objective: Present basic statistics for numerical columns_

# %%
numerical_columns = data.select_dtypes(include=['number']).columns
print("Numerical Columns:", numerical_columns)
# Out:
# Numerical Columns: Index(['age', 'Mutual_Funds', 'Equity_Market', 'Debentures',
#        'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold'],
#       dtype='object')

# %%
# Calculating basic statistics
stats = {
    'mean': data[numerical_columns].mean(),
    'median': data[numerical_columns].median(),
    'std': data[numerical_columns].std()
}

# Combining statistics into a DataFrame
stats_df = pd.DataFrame(stats)
print(stats_df)
# Out:
#                     mean  median       std
# age               27.800    27.0  3.560467
# Mutual_Funds       2.550     2.0  1.197219
# Equity_Market      3.475     4.0  1.131994
# Debentures         5.750     6.5  1.675617
# Government_Bonds   4.650     5.0  1.369072
# Fixed_Deposits     3.575     3.5  1.795828
# PPF                2.025     1.0  1.609069
# Gold               5.975     6.0  1.143263

# %% [markdown]
# ### Basic analysis till now :
# _The above statistics reveals that the majority of individuals in the dataset are young, with an average age of 27.8 years. Among the investment avenues, **Gold** (mean: 5.975) and **Debentures** (mean: 5.75) are the most favored options, indicating a preference for secure and tangible investments. Conversely, **PPF (Public Provident Fund)** is the least preferred (mean: 2.025), suggesting limited interest in long-term government savings schemes. The variability is relatively low across most columns, indicating consistent investment preferences within the group_

# %% [markdown]
# ## Task 4 : Most Preferred Investment Avenue
# _Objective: Identify the most preferred investment avenue_

# %%
# Sum each investment avenue to find total preference scores
investment_totals = data[['Mutual_Funds', 'Equity_Market', 'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold']].sum()

# Find the most preferred investment avenue
most_preferred = investment_totals.idxmax()
print(f"Most Preferred Investment Avenue: {most_preferred} (Total: {investment_totals[most_preferred]})")
# Out:
# Most Preferred Investment Avenue: Gold (Total: 239)

# %% [markdown]
# ## Task 5: Reasons for Investment
# _Objective: Analyze and summarize reasons for investment choices_

# %%
reason_columns = ['Reason_Equity', 'Reason_Mutual', 'Reason_Bonds', 'Reason_FD']
reasons_data = data[reason_columns].melt(var_name='Investment_Type', value_name='Reason')
reason_counts = reasons_data['Reason'].value_counts()

plt.figure(figsize=(10, 6))
reason_counts.plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title('Reasons for Investment Choices', fontsize=16)
plt.xlabel('Reason', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Summary :
# The chart shows that "Capital Appreciation," "Assured Returns," and "Better Returns" are the top reasons for investment. Other factors like "Risk-Free" and "Safe Investment" are moderately important, while tax and liquidity considerations are less prioritized.

# %% [markdown]
# ## Task 6: Savings Objectives
#
# _Objective: Identify and present main savings objectives_

# %%
saving_Objective = data['What are your savings objectives?'].value_counts()

plt.figure(figsize=(8, 5))
saving_Objective.plot(kind='bar', color='skyblue', edgecolor='black')

plt.title('Saving objective', fontsize=16)
plt.xlabel('saving_objective', fontsize=14)
plt.xticks(rotation=0, fontsize=10)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Retirement Plan'),
#   Text(1, 0, 'Health Care'),
#   Text(2, 0, 'Education')])

# %% [markdown]
# ### _Saving objective summary_:
#
# The primary savings objective among participants is **Retirement Planning**, accounting for the majority (24 responses). This indicates a strong focus on long-term financial security. **Health Care** ranks second with 13 responses, reflecting concern for medical expenses and unforeseen health-related costs. Lastly, **Education** is mentioned by 3 participants, highlighting a smaller yet important focus on funding educational goals.
#
# This distribution suggests that most participants prioritize stability and preparedness for life’s major events over other potential objectives.

# %% [markdown]
# ## Task 7: Common Information Sources
# _Objective: Analyze common sources participants rely on for investment information_

# %%
info_sources = data['Source'].value_counts()
print(info_sources)
# Out:
# Source
# Financial Consultants       16
# Newspapers and Magazines    14
# Television                   6
# Internet                     4
# Name: count, dtype: int64

# %%
info_sources = {
    "Financial Consultants": 16,
    "Newspapers and Magazines": 14,
    "Television": 6,
    "Internet": 4
}

labels = info_sources.keys()
sizes = info_sources.values()

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightgreen', 'orange', 'pink'])
plt.title("Common Sources of Investment Information")
plt.show()

# %% [markdown]
# _The pie chart reveals that Financial Consultants (40%) and Newspapers and Magazines (35%) are the most relied-upon sources of investment information, indicating participants prefer professional advice and printed media. Television (15%) and the Internet (10%) play a smaller role_

# %% [markdown]
# ## Task 8: Investment Duration Where Data Meets Intelligence
# _Objective: Calculate the average investment duration_

# %%
duration_mapping = {
    "Less than 1 year": 0.5,
    "1-3 years": 2,
    "3-5 years": 4,
    "More than 5 years": 6
}

data['Duration'] = data['Duration'].map(duration_mapping)

average_duration = data['Duration'].mean()

print(f"Average Investment Duration: {average_duration:.2f} years")
# Out:
# Average Investment Duration: 2.98 years

# %% [markdown]
# * So average duration of investment is 2.98 or we can say 3 years approximately

# %% [markdown]
# ## Task 9: Expectations from Investments
# _Objective: Summarize participants' expectations from investments_

# %%
print(data['Expect'].value_counts())
# Out:
# Expect
# 20%-30%    32
# 30%-40%     5
# 10%-20%     3
# Name: count, dtype: int64

# %%
expectations = data['Expect'].value_counts()
plt.figure(figsize=(10, 6))
expectations.plot(kind='bar', color='skyblue')
plt.title('Participants’ Expectations from Investments')
plt.xlabel('Expectations')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
common_expectations = expectations.index.tolist()[:3]  # Top 3 expectations
print(f"The most common expectations from investments are: {', '.join(common_expectations)}.")
# Out:
# The most common expectations from investments are: 20%-30%, 30%-40%, 10%-20%.

# %% [markdown]
# As we can see from the above graph, Maximum number of people are expecting 20%-30%

# %% [markdown]
# ## Task 10: Correlation Analysis
# _Objective: Explore potential correlations between factors_

# %%
numerical_data = data.select_dtypes(include=['number'])
correlation_matrix = numerical_data.corr()
print(correlation_matrix)
# Out:
#                        age  Mutual_Funds  Equity_Market  Debentures  \
# age               1.000000     -0.123914       0.246840    0.326638
# Mutual_Funds     -0.123914      1.000000       0.332043   -0.351495
# Equity_Market     0.246840      0.332043       1.000000   -0.016898
# Debentures        0.326638     -0.351495      -0.016898    1.000000
# Government_Bonds -0.093632     -0.114198      -0.237420    0.430323
# Fixed_Deposits   -0.033685     -0.031604      -0.238705   -0.470791
# PPF              -0.263167     -0.193665      -0.429003   -0.511169
# Gold             -0.057952     -0.401830      -0.050027   -0.137195
# Duration          0.051756      0.184528       0.471251    0.034367
#
#                   Government_Bonds  Fixed_Deposits       PPF      Gold  \
# age                      -0.093632       -0.033685 -0.263167 -0.057952
# Mutual_Funds             -0.114198       -0.031604 -0.193665 -0.401830
# Equity_Market            -0.237420       -0.238705 -0.429003 -0.050027
# ...

# %%
#visualization:

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Between All Variables")
plt.show()

# %% [markdown]
# **Key insights include:**
#
# * A moderate positive correlation between Equity Market and Debentures (0.33), and Equity Market and Mutual Funds (0.25)
# * Fixed Deposits, PPF, and Government Bonds show weak or no significant correlation with most other variables.
# * Age has minimal correlation with investments, indicating that age might not directly influence investment preferences in this dataset.
